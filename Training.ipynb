# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.1/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image #untuk menampilkan gambar

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="C1iVLGj5UQ6RIACDdgL3")
project = rf.workspace("roboflow-klb4b").project("objectdetection-lrf4u")
version = project.version(4)
dataset = version.download("yolov8-obb")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/ObjectDetection-1/data.yaml epochs=75 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 234MB/s]
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
